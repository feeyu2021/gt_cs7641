# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import mlrose_hiive
import matplotlib.pyplot as plt
import time
from random import randint
import random
import numpy as np 
import pandas as pd
from util import *

# %% [markdown]
# # onemax

# %%
fitness_fourpeaks = mlrose_hiive.OneMax()
fitness = fitness_fourpeaks
problem_length = 100
problem = mlrose_hiive.DiscreteOpt(length = problem_length, fitness_fn = fitness, maximize = True)

# %%
para_tune(problem
              , algo_key = 'RHC'
              , paras = ('max_attempts',[10,100, 1000,10000])
              , trials = 10)
# Out:
# RHC with max_attempts = 10: time: 0.0012000000000000001, best fitness: 81.5
# RHC with max_attempts = 100: time: 0.009600000000000001, best fitness: 99.7
# RHC with max_attempts = 1000: time: 0.028800000000000003, best fitness: 100.0
# RHC with max_attempts = 10000: time: 0.09259999999999999, best fitness: 100.0

# %%
para_tune(problem
              , algo_key = 'SA'
              , paras = ('max_attempts',[10,100, 1000, 10000])
            , trials = 10
             )
# Out:
# SA with max_attempts = 10: time: 0.0044, best fitness: 84.9
# SA with max_attempts = 100: time: 0.0128, best fitness: 99.5
# SA with max_attempts = 1000: time: 0.03969999999999999, best fitness: 100.0
# SA with max_attempts = 10000: time: 0.1301, best fitness: 100.0

# %%
para_tune(problem
              , algo_key = 'GA'
              , paras = ('max_attempts',[10,25,50])
              , trials = 10
              , kwargs = {'mutation_prob':0.99}
             )
# Out:
# GA with max_attempts = 10: time: 0.5875999999999999, best fitness: 100.0
# GA with max_attempts = 25: time: 0.7882, best fitness: 100.0
# GA with max_attempts = 50: time: 1.1263999999999998, best fitness: 100.0

# %%
para_tune(problem
              , algo_key = 'GA'
              , paras = ('mutation_prob',[0.1,0.5, 0.99])
              , trials = 10
              , kwargs = {'max_attempts':25}
             )
# Out:
# GA with mutation_prob = 0.1: time: 0.7655, best fitness: 100.0
# GA with mutation_prob = 0.5: time: 0.7836000000000001, best fitness: 100.0
# GA with mutation_prob = 0.99: time: 0.7767, best fitness: 100.0

# %%
problem.set_mimic_fast_mode(True)
para_tune(problem
              , algo_key = 'MIMIC'
              , paras = ('max_attempts',[10,15,20])
              , trials = 5
              , kwargs = {}
             )
# Out:
# MIMIC with max_attempts = 10: time: 1.1982000000000002, best fitness: 99.6
# MIMIC with max_attempts = 15: time: 1.5978, best fitness: 99.8
# MIMIC with max_attempts = 20: time: 1.7748000000000002, best fitness: 100.0

# %%
para_tune(problem
              , algo_key = 'MIMIC'
              , paras = ('keep_pct',[0.1, 0.2, 0.3])
              , trials = 5
              , kwargs = {'max_attempts':10}
             )
# Out:
# MIMIC with keep_pct = 0.1: time: 0.9861999999999999, best fitness: 95.8
# MIMIC with keep_pct = 0.2: time: 0.9387999999999999, best fitness: 99.0
# MIMIC with keep_pct = 0.3: time: 1.0863999999999998, best fitness: 100.0
